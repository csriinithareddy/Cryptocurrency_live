# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
#When you are using your own key, replace the sandbox url with the on ein the documentation.
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'20',
  'convert':'USD'
}
# Here replace the key with the key that you have
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fe43d1a8-158d-43e0-8d1f-b002a79d0aaa',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #To test in sagemaker, for time being I'm commenting all the print comments
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
#So, initially when you start running this, you get a warning message that says that the data limit must be increased.
# for this, go to anaconda prompt and type the msg
#jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10 --(And after this, it just open up a new page and in that it runs)
"""
We are making use of the Request library to start a session to do an API call. We are importing the JSON library
as the data is formatted in JSON. The url parameter is used to state the url from which we are scraping data and it
always loads latest data, and paramters variable to start and when to stop scraping the data. We later use the headers to
input the key, the the type of data format that must be accepted. We later write a try statement after opening a session and
throw an error if anything goes unexpected variable is used to mention.
"""
# Out:
# '\nWe are making use of the Request library to start a session to do an API call. We are importing the JSON library \nas the data is formatted in JSON. The url parameter is used to state the url from which we are scraping data and it \nalways loads latest data, and paramters variable to start and when to stop scraping the data. We later use the headers to \ninput the key, the the type of data format that must be accepted. We later write a try statement after opening a session and \nthrow an error if anything goes unexpected variable is used to mention. \n'

# %%
# The type in which the data is formatted
# supposed keys are 'status', 'data'
type(data)
# Out:
# dict

# %%
#we try to convert the dictionary to a dataframe
# Using pandas to normalize the JSON-like object and create a DataFrame
#The rest of the information is just status, but the actual key we want is "data"
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.json_normalize(data['data'])

# %%
# Now, we automate the process of API calls
#we create a column to to store the time at which data is collected/updated
df['timestamp'] = pd.to_datetime('now')
# Out:
# <ipython-input-4-bc6394ddf3ae>:3: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')

# %%
df
# retrieving col names
#col_names = df.columns.tolist()
#print(col_names)
# Out:
#        id               name symbol                  slug  num_market_pairs  \
# 0       1            Bitcoin    BTC               bitcoin             10704
# 1    1027           Ethereum    ETH              ethereum              8242
# 2     825        Tether USDt   USDT                tether             71293
# 3    1839                BNB    BNB                   bnb              2008
# 4    5426             Solana    SOL                solana               613
# 5      52                XRP    XRP                   xrp              1199
# 6    3408               USDC   USDC              usd-coin             16187
# 7    2010            Cardano    ADA               cardano              1023
# 8    5805          Avalanche   AVAX             avalanche               636
# 9      74           Dogecoin   DOGE              dogecoin               872
# 10   1958               TRON    TRX                  tron               895
# 11   6636           Polkadot    DOT          polkadot-new               661
# 12   1975          Chainlink   LINK             chainlink              1566
# 13   3890            Polygon  MATIC               polygon              1239
# 14  11419            Toncoin    TON               toncoin               187
# 15   8916  Internet Computer    ICP     internet-computer               201
# 16   5994          Shiba Inu   SHIB             shiba-inu               723
# 17   4943                Dai    DAI  multi-collateral-dai              2980
# 18      2           Litecoin    LTC              litecoin              1079
# 19   1831       Bitcoin Cash    BCH          bitcoin-cash               825
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-07-13T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2019-04-28T00:00:00.000Z
# 14  2021-08-26T13:40:22.000Z
# 15  2021-03-23T00:00:00.000Z
# 16  2020-08-01T00:00:00.000Z
# 17  2019-11-22T00:00:00.000Z
# 18  2013-04-28T00:00:00.000Z
# 19  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 8   [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
# 9   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 10  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 12  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 13  [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 14  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 15  [platform, ai-big-data, collectibles-nfts, def...           NaN
# 16      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 17  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 18        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 19  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.959828e+07  1.959828e+07            False       NaN         1
# 1         1.201817e+08  1.201817e+08             True       NaN         2
# 2         9.501084e+10  9.860296e+10             True       NaN         3
# 3         1.516898e+08  1.516898e+08            False       NaN         4
# 4         4.325472e+08  5.670599e+08             True       NaN         5
# 5         5.426682e+10  9.998801e+10            False       NaN         6
# 6         2.547657e+10  2.547657e+10            False       NaN         7
# 7         3.539029e+10  3.652824e+10            False       NaN         8
# 8         3.666453e+08  4.346782e+08            False       NaN         9
# 9         1.426444e+11  1.426444e+11             True       NaN        10
# 10        8.824084e+10  8.824084e+10             True       NaN        11
# 11        1.267103e+09  1.399363e+09             True       NaN        12
# 12        5.681000e+08  1.000000e+09            False       NaN        13
# 13        9.562653e+09  1.000000e+10            False       NaN        14
# 14        3.456651e+09  5.101116e+09             True       NaN        15
# 15        4.554213e+08  5.132376e+08             True       NaN        16
# 16        5.892906e+14  5.895347e+14            False       NaN        17
# 17        5.347889e+09  5.347889e+09             True       NaN        18
# 18        7.409121e+07  8.400000e+07            False       NaN        19
# 19        1.961323e+07  1.961323e+07            False       NaN        20
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              8.343828e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                      3.414167e+09              7.160762e+09      None
# 15                      4.554214e+08              6.109389e+09      None
# 16                               NaN                       NaN      None
# 17                               NaN                       NaN      None
# 18                               NaN                       NaN      None
# 19                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-01-14T06:05:00.000Z     42767.785865          1.713260e+10
# 1   2024-01-14T06:05:00.000Z      2552.864637          1.087517e+10
# 2   2024-01-14T06:04:00.000Z         0.999626          3.496415e+10
# 3   2024-01-14T06:04:00.000Z       303.903808          7.784234e+08
# 4   2024-01-14T06:05:00.000Z        97.447883          1.955896e+09
# 5   2024-01-14T06:05:00.000Z         0.574741          6.012773e+08
# 6   2024-01-14T06:05:00.000Z         1.000087          4.130259e+09
# 7   2024-01-14T06:04:00.000Z         0.547342          3.329064e+08
# 8   2024-01-14T06:04:00.000Z        36.816386          4.753430e+08
# 9   2024-01-14T06:05:00.000Z         0.080803          2.758629e+08
# 10  2024-01-14T06:04:00.000Z         0.116437          6.521651e+08
# 11  2024-01-14T06:04:00.000Z         7.593461          1.783412e+08
# 12  2024-01-14T06:04:00.000Z        15.005570          3.604587e+08
# 13  2024-01-14T06:04:00.000Z         0.879079          2.917447e+08
# 14  2024-01-14T06:05:00.000Z         2.097367          4.282279e+07
# 15  2024-01-14T06:04:00.000Z        13.414804          2.152314e+08
# 16  2024-01-14T06:04:00.000Z         0.000010          1.202263e+08
# 17  2024-01-14T06:04:00.000Z         1.000055          2.400402e+08
# 18  2024-01-14T06:05:00.000Z        71.529580          3.449668e+08
# 19  2024-01-14T06:04:00.000Z       254.849899          2.685041e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                
+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-01-14T06:05:00.000Z          NaN           NaN
# 1           None  2024-01-14T06:05:00.000Z          NaN           NaN
# 2           None  2024-01-14T06:04:00.000Z       1027.0      Ethereum
# 3           None  2024-01-14T06:04:00.000Z          NaN           NaN
# 4           None  2024-01-14T06:05:00.000Z          NaN           NaN
# 5           None  2024-01-14T06:05:00.000Z          NaN           NaN
# 6           None  2024-01-14T06:05:00.000Z       1027.0      Ethereum
# 7           None  2024-01-14T06:04:00.000Z          NaN           NaN
# 8           None  2024-01-14T06:04:00.000Z          NaN           NaN
# 9           None  2024-01-14T06:05:00.000Z          NaN           NaN
# 10          None  2024-01-14T06:04:00.000Z          NaN           NaN
# 11          None  2024-01-14T06:04:00.000Z          NaN           NaN
# 12          None  2024-01-14T06:04:00.000Z       1027.0      Ethereum
# 13          None  2024-01-14T06:04:00.000Z          NaN           NaN
# 14          None  2024-01-14T06:05:00.000Z          NaN           NaN
# 15          None  2024-01-14T06:04:00.000Z          NaN           NaN
# 16          None  2024-01-14T06:04:00.000Z       1027.0      Ethereum
# 17          None  2024-01-14T06:04:00.000Z       1027.0      Ethereum
# 18          None  2024-01-14T06:05:00.000Z          NaN           NaN
# 19          None  2024-01-14T06:04:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
# 15             NaN           NaN                                         NaN
# 16             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 17             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 18             NaN           NaN                                         NaN
# 19             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-01-14 06:06:22.686258
# 1  2024-01-14 06:06:22.686258
# 2  2024-01-14 06:06:22.686258
# 3  2024-01-14 06:06:22.686258
# 4  2024-01-14 06:06:22.686258
# 5  2024-01-14 06:06:22.686258
# 6  2024-01-14 06:06:22.686258
# 7  2024-01-14 06:06:22.686258
# 8  2024-01-14 06:06:22.686258
# 9  2024-01-14 06:06:22.686258
# 10 2024-01-14 06:06:22.686258
# 11 2024-01-14 06:06:22.686258
# 12 2024-01-14 06:06:22.686258
# 13 2024-01-14 06:06:22.686258
# 14 2024-01-14 06:06:22.686258
# 15 2024-01-14 06:06:22.686258
# 16 2024-01-14 06:06:22.686258
# 17 2024-01-14 06:06:22.686258
# 18 2024-01-14 06:06:22.686258
# 19 2024-01-14 06:06:22.686258

# %%
def automate_api():
    #when the function call happens, the variable df is considered as a local variable, and hence it raises an error saying
    # that it is used before assignment, hence we declare it as glabal
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'20',
      'convert':'USD'
    }
# Here replace the key with the key that you have
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'fe43d1a8-158d-43e0-8d1f-b002a79d0aaa',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    #Here we already have the original data frame setup at top, so the data we get must be appended to the existing dataframe
    #after retrieving data, it is normalized and stored in the dataframe with the time stamp

    # commenting all this as I want to copy the data to csv
    pd.set_option('display.max_columns', None)
    df_latest = pd.json_normalize(data['data'])
    df_latest['timestamp'] = pd.to_datetime('now')
    #Now, here as you want to append data to the original dataframe i.e df
    df = df.append(df_latest, ignore_index = True)
    #If this doesn't work try running the same jypyter statement in the prompt.

    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df

    #if not os.path.isfile(r'"C:\Users\hp\Downloads\API.csv'):
     #   df.to_csv(r'"C:\Users\hp\Downloads\API.csv', header='column_names')
    #else:
    #    df.to_csv(r'"C:\Users\hp\Downloads\API.csv', mode='a', header=False)

# %%
#
import os
from time import time
from time import sleep
try:
    # Your code here
    for i in range(5):
        automate_api()
        print("Process completed!")
    #After calling the function, the script waits for 5 seconds before starting the loop again
        sleep(5)
    #exit()
except Exception as e:
    print(f"An error occurred: {e}")

#for i in range(5):
   # automate_api()
   # print("Process completed!")
    #After calling the function, the script waits for 5 seconds before starting the loop again
   # sleep(5)
#exit()
# Out:
# <ipython-input-6-f9ef44b85bfe>:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df_latest['timestamp'] = pd.to_datetime('now')
# <ipython-input-6-f9ef44b85bfe>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_latest, ignore_index = True)
# Process completed!
# <ipython-input-6-f9ef44b85bfe>:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df_latest['timestamp'] = pd.to_datetime('now')
# <ipython-input-6-f9ef44b85bfe>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_latest, ignore_index = True)
# Process completed!
# <ipython-input-6-f9ef44b85bfe>:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df_latest['timestamp'] = pd.to_datetime('now')
# <ipython-input-6-f9ef44b85bfe>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_latest, ignore_index = True)
# Process completed!
# <ipython-input-6-f9ef44b85bfe>:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df_latest['timestamp'] = pd.to_datetime('now')
# <ipython-input-6-f9ef44b85bfe>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_latest, ignore_index = True)
# Process completed!
# <ipython-input-6-f9ef44b85bfe>:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df_latest['timestamp'] = pd.to_datetime('now')
# <ipython-input-6-f9ef44b85bfe>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_latest, ignore_index = True)
# Process completed!

# %%
#df

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
#df
# I wrote this, just to understand the data
#first_20_rows = df.head(22)

# Display the first 20 rows
#print(first_20_rows)

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d','num_market_pairs','circulating_supply','total_supply','quote.USD.price','quote.USD.volume_24h', 'quote.USD.volume_change_24h','quote.USD.market_cap', 'quote.USD.market_cap_dominance', 'quote.USD.fully_diluted_market_cap']].mean()
#df3

# %%
#stacking them up now to perform useful visualizations, we need to pivot it
df4 = df3.stack()
#df4

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
#df5
#type(df5)

# %%
#You have to make this dynamic(like the count has to be retrived)
df5_count = df5.count()['values']
#print(df5_count)
# REMEMBER THAT YOU HAVE TO GENERATE THIS COUNT VARIABLE DYNAMICALLY
#

# %%
# indexing the dataset now
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(df5_count))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
#df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
#df7

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d','num_market_pairs','quote.USD.price','quote.USD.market_cap','quote.USD.market_cap_dominance','quote.USD.fully_diluted_market_cap','quote.USD.percent_change_1h'],['24h','7d','30d','60d','90d','market_pairs','price_in_USD','market_cap','market_cap_dominance','fully_diluted_market_cap','1hr'])
#df7

# %%
#trying to write the final data frame to a csv file, let's see if this works!
#Yep, this works
# we changed the mode to W--new data gets added.
if not os.path.isfile(r'API.csv'):
    df7.to_csv(r'API.csv', header='column_names')
else:
    df7.to_csv(r'API.csv', mode='w', header=False)

# %%
# First way to schedule
# 2nd method is by using AWS lambda and sage maker to
